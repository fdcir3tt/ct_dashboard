# %% [markdown]
# # Modelo de Impulso Extremo de Gradiente (XGBoost)
#
# ## Arboles de decisión
#
# ## Impulso de Arboles

# %% [markdown]
# # Referencias
#
# [Introduction to Boosted Trees](https://xgboost.readthedocs.io/en/stable/tutorials/model.html)
# [¿Qué es XGBoost?](https://www.ibm.com/mx-es/think/topics/xgboost)
